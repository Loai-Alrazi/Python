# %%
import numpy as np
import random

# %%
a = np.array([1,2,3])
b = np.array([[1.5,3.4,2.4],[3.7, 8.2,5.]], dtype= float)

# %%
arr = np.arange(5)
arr
# Out:
# array([0, 1, 2, 3, 4])

# %%
arr = np.arange(0,11,2)
arr

# %%
arr = np.zeros((2,3))
arr

# %%
arr = np.ones((3,4))
arr

# %%
arr= np.linspace(1,2,5)
arr

# %% [raw]
# arr = np.random.randint(20,50,10)
# arr

# %% [markdown]
# # Inspecting Numpy Arrays

# %%
a.shape

# %%
len (b)

# %%
a.ndim

# %%
b.size

# %%
b.dtype

# %%
b.astype(int)

# %%
np.insert(a,1,9)

# %%
np.delete(a,2)

# %%
b.reshape(3,2)
# Out:
# array([[1.5, 3.4],
#        [2.4, 3.7],
#        [8.2, 5. ]])

# %%
d= np.append(a,b)
d
# Out:
# array([1. , 2. , 3. , 5. , 1.5, 3.4, 2.4, 3.7, 8.2, 5. ])

# %% [markdown]
# # Subsetting, Slicing, & Indexing

# %%
a
# Out:
# array([1, 2, 3, 5])

# %%
a[2]
# Out:
# 3

# %%
b
# Out:
# array([[1.5, 3.4, 2.4],
#        [3.7, 8.2, 5. ]])

# %%
b[1][2]
# Out:
# 5.0

# %% [markdown]
# # Numpy Array Mathematics

# %%
a
# Out:
# array([1, 2, 3, 5])

# %%
b
# Out:
# array([[1.5, 3.4, 2.4],
#        [3.7, 8.2, 5. ]])

# %%
b+a
# Out:
# array([[ 2.5,  5.4,  5.4],
#        [ 4.7, 10.2,  8. ]])

# %%
c=np.add(b,a)
c
# Out:
# array([[ 2.5,  5.4,  5.4],
#        [ 4.7, 10.2,  8. ]])

# %%
d=np.subtract(b,a)
d
# Out:
# array([[ 0.5,  1.4, -0.6],
#        [ 2.7,  6.2,  2. ]])

# %%
np.multiply(a,b)
# Out:
# array([[ 1.5,  6.8,  7.2],
#        [ 3.7, 16.4, 15. ]])

# %%
np.sqrt(b)
# Out:
# array([[1.22474487, 1.84390889, 1.54919334],
#        [1.92353841, 2.86356421, 2.23606798]])

# %%
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.log(c)
# Out:
# array([[0.91629073, 1.68639895, 1.68639895],
#        [1.54756251, 2.32238772, 2.07944154]])

# %% [markdown]
# # NumPy Statistical Operations

# %%
a.sum()
# Out:
# 6

# %%
b.min()
# Out:
# 1.5

# %%
a.max()
# Out:
# 3

# %%
a.mean()
# Out:
# 2.0

# %%
np.median(a)
# Out:
# 2.0

# %%
np.std(a)
# Out:
# 0.816496580927726
