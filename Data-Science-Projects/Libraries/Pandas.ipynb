# %% [markdown]
# # Pandas Data Structures

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Series

# %%
s=pd.Series([1,-4,6,0],index=['A','B','C','D'])
s
# Out:
# A    1
# B   -4
# C    6
# D    0
# dtype: int64

# %%
lis1= np.random.randint(-10,10,size=6)
lis1
# Out:
# array([ 8,  1, -8,  6,  9, -1])

# %%
ser1=pd.Series(lis1, index=['01','02','03','04','05','06'])
ser1
# Out:
# 01    8
# 02    1
# 03   -8
# 04    6
# 05    9
# 06   -1
# dtype: int32

# %%
ser2=pd.Series({'Mon':True ,'Sun':False ,'Sat':True,'fri':False,'Tues':False,'Thers':False})
ser2
# Out:
# Mon       True
# Sun      False
# Sat       True
# fri      False
# Tues     False
# Thers    False
# dtype: bool

# %%
ser3= pd.Series(120, index= np.arange(1,11))
ser3
# Out:
# 1     120
# 2     120
# 3     120
# 4     120
# 5     120
# 6     120
# 7     120
# 8     120
# 9     120
# 10    120
# dtype: int64

# %% [markdown]
# # Pandas DataFrame
